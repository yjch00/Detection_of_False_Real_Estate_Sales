# %%
import requests
import copy
import csv
import time
import json
import uuid
import pprint
import asyncio
from typing import List
from urllib import parse
from urllib.parse import quote
import inspect
import datetime

# %%
class magic_fstring_function:
    def __init__(self, payload):
        self.payload = payload
        self.cached = None
    def __str__(self):
        if self.cached is None:
            vars = inspect.currentframe().f_back.f_globals.copy()
            vars.update(inspect.currentframe().f_back.f_locals)
            self.cached = self.payload.format(**vars)
        return self.cached

# %%
uuid = str(uuid.uuid4())
item_list_api = "https://apis.zigbang.com/v2/items"
describe_list_api = item_list_api + '/list'
item_describe_api = "https://apis.zigbang.com/v3/items?item_ids={item_id}&detail=true"
item_view_url = "https://zigbang.com/home/oneroom/items/{item_id}"

referer = "https://zigbang.com/home/oneroom/subways/414/items"
        
headers = {
    'Host':'apis.zigbang.com',
    'Connection':'keep-alive',
    'Pragma':'no-cache',
    'Cache-Control':'no-cache',
    'Accept':'application/json, text/plain, */*',
    'Origin':'https://zigbang.com',
    'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Mobile Safari/537.36',
    'DNT':'1',
    'Sec-Fetch-Site':'same-site',
    'Sec-Fetch-Mode':'cors',
    'Referer':'https://zigbang.com/home/oneroom/subways/414/items',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
}

items = {}
sad_words = [ '대출x', '대출불가', '전세 안됩']

# %%
def export_items(items):
    fieldnames = [
        'id',
        'title',
        'description',
        'deposit',
        'agent_name',
        'agent_mobile',
        '_floor',
        'address1',
        'address2',
        'address3',
        'size',
        'size_m2',
        'status',
        'room_type',
        'manage_cost_inc',
        'updated_at2',
        'url',
    ]
    
    filtered_item = [] 
    maximum_updated = datetime.timedelta(days=4)
    
    wish = '대출'
    for item in items:
        item = item['item']
        if wish in item['title'] or wish in item['description']:
            plz_flag = True
            for word in sad_words:
                if word in item['description']:
                    plz_flag = False
                    break
            if not plz_flag:
                continue
            item_updated = datetime.datetime.strptime(item['updated_at2'], '%Y-%m-%d')
            if maximum_updated < datetime.datetime.now() - item_updated:
                continue
            item_id = item['id']
            url = magic_fstring_function(item_view_url)
            item['url'] = str(url)
            new_item = {}
            for fieldname in fieldnames:
                new_item[fieldname] = item[fieldname]
            filtered_item.append(new_item)
    return filtered_item
def describe_room_list(items):
    item_ids = list(items.keys())
    max_idx = int(len(item_ids) / 30)
    if len(item_ids) % 30 != 0:
        max_idx += 1
    
    items = []
    headers['Accept'] = 'application/json'
    headers['Referer'] = 'https://zigbang.com/home/oneroom/subways/37/items'
    
    for i in range(max_idx):
        start_idx = i * 30
        end_idx = min((i+1)*30, len(item_ids))
        sub_ids = item_ids[start_idx:end_idx-1]
        item_id = str(sub_ids).replace(' ', '').replace('\'','')
        api = magic_fstring_function(item_describe_api)
        g = api
        resp = requests.get(
            url=str(api),
            headers=headers,
            timeout=5,
        )
        resp.encoding = 'utf-8'
        result = resp.json()
        resp.close()
        items += result['items']
        time.sleep(1)
        
    return items
def get_room_list(
    items,
    deposit_gteq: int = 0,
    deposit_lteq: int = 8000,
    domain: str = "zigbang",
    floor_in: str = "ground",
    geohash: str = "wydjr",
    rent_gteq: int = 0,
    sales_type_in: str = "월세",
    service_type_eq: str = "원룸",
):
    resp = requests.get(
        url=item_list_api,
        params={
            "deposit_gteq": deposit_gteq,
            "deposit_lteq": deposit_lteq,
            "domain": domain,
            "floor_in": floor_in,
            "geohash": geohash,
            "rent_gteq": rent_gteq,
            "sales_type_in": sales_type_in,
            "service_type_eq": service_type_eq,
        },
        headers=headers,
        timeout=5,
    )
    new_items = json.loads(resp.content.decode('utf-8'))
    resp.close()

    for section in new_items['sections']:
        for item in section['item_ids']:
            items[str(item)] = {}

    return items

# %%
items = {}
geos_sinrim = [
    'wydm0',
    'wydm1',
    'wydm2',
   'wydm3',
] 

for geo in geos_sinrim:
    items = get_room_list(items, geohash=geo)
    time.sleep(1)

# %%
len(items)
# Out:
# 2128

# %%
result = describe_room_list(items)
len(result)
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(result[0]['item'])
# Out:
# { '_floor': '3층',
#   'address1': '서울시 관악구 봉천동',
#   'address2': '41-670',
#   'address3': None,
#   'agent_address1': '서울특별시 관악구 관악로16길 42 1층(봉천동)',
#   'agent_comment': '',
#   'agent_email': 'cjsrlgh1@gmail.com',
#   'agent_lat': 37.479643300561705,
#   'agent_lng': 126.954969531442,
#   'agent_local1': '서울시',
#   'agent_local2': '관악구',
#   'agent_mobile': '010-9596-0920',
#   'agent_name': '구름공인중개사사무소(천기호)',
#   'agent_no': 71941,
#   'agent_phone': '010-9596-0920',
#   'bjd_code': '',
#   'bonbun_code': '41',
#   'bubun_code': '670',
#   'building': None,
#   'building_type': '다세대건물',
#   'contract': '서울특별시',
#   'deposit': 1000,
#   'description': '💖💖매물로 승부봅니다.💖💖\r\n'
#                  '✨더 좋은방, 더 싸게✨\r\n'
#                  '\r\n'
#                  '✅ 서울대입구역 7분\r\n'
#                  '✅ 방1, 욕실1\r\n'
#                  '✅ 현관보안, 에어컨, 세탁기, 냉장고, 옷장 등 풀옵션!!\r\n'
#                  '\r\n'
#                  '≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡\r\n'
#                  '\r\n'
#                  '✨방 구조✨\r\n'
#                  '✔ 오픈형 원룸(방1, 욕실1,)\r\n'
#                  '✔ 구조 좋습니다.\r\n'
#                  '\r\n'
#                  '✨주변 인프라✨\r\n'
#                  '✔ 대로변 가까운 위치에 있어 입지 좋습니다.\r\n'
#                  '✔ 카페, 빨래방, 편의점 등 다있어요~\r\n'
#                  '\r\n'
#                  '✨기타사항✨\r\n'
#                  '✔ 풀옵션으로 몸만 들어오셔서 바로 사용하시면 됩니다.\r\n'
#                  '✔ 비슷한 금액, 비슷한 스타일 매물 다량 보유\r\n'
#                  '\r\n'
#                  '✅ 허위, 과장 매물은 존재하지 않습니다. (제 얼굴 걸고 중개합니다😊)\r\n'
#                  '✅ 항상 고객님의 편에 서서 끝까지 책임지겠습니다.\r\n'
#                  '✅ 친절, 정직 중개로 부담 없이 마음에 드실 집 소개해드립니다.\n'
#                  '22.04.11에 직방에 등록된 매물입니다.',
#   'description_og': '&#128150;&#128150;매물로 승부봅니다.&#128150;&#128150;\r\n'
#                     '✨더 좋은방, 더 싸게✨\r\n'
#                     '\r\n'
#                     '✅ 서울대입구역 7분\r\n'
#                     '✅ 방1, 욕실1\r\n'
#                     '✅ 현관보안, 에어컨, 세탁기, 냉장고, 옷장 등 풀옵션!!\r\n'
#                     '\r\n'
#                     '≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡\r\n'
#                     '\r\n'
#                     '✨방 구조✨\r\n'
#                     '✔ 오픈형 원룸(방1, 욕실1,)\r\n'
#                     '✔ 구조 좋습니다.\r\n'
#                     '\r\n'
#                     '✨주변 인프라✨\r\n'
#                     '✔ 대로변 가까운 위치에 있어 입지 좋습니다.\r\n'
#                     '✔ 카페, 빨래방, 편의점 등 다있어요~\r\n'
#                     '\r\n'
#                     '✨기타사항✨\r\n'
#                     '✔ 풀옵션으로 몸만 들어오셔서 바로 사용하시면 됩니다.\r\n'
#                     '✔ 비슷한 금액, 비슷한 스타일 매물 다량 보유\r\n'
#                     '\r\n'
#                     '✅ 허위, 과장 매물은 존재하지 않습니다. (제 얼굴 걸고 중개합니다&#128522;)\r\n'
#                     '✅ 항상 고객님의 편에 서서 끝까지 책임지겠습니다.\r\n'
#                     '✅ 친절, 정직 중개로 부담 없이 마음에 드실 집 소개해드립니다.\n'
#                     '22.04.11에 직방에 등록된 매물입니다.',
#   'elevator': '없음',
#   'floor': '3층',
#   'floor_all': '4층',
#   'id': 31371359,
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/7.jpg'},
#               { 'count': 8,
#                 'index': 7,
#                 'url': 'https://ic.zigbang.com/ic/items/31371359/8.jpg'}],
#   'images_thumbnail': '/items/31371359/1.jpg',
#   'is_deposit_only': False,
#   'is_direct': False,
#   'is_homepage': True,
#   'is_owner': False,
#   'is_premium': True,
#   'is_premium2': True,
#   'is_realestate': True,
#   'is_room': False,
#   'is_status_close': False,
#   'is_status_open': True,
#   'is_type_room': False,
#   'is_zzim': False,
#   'loan_text': '확인필요',
#   'local1': '서울시',
#   'local2': '관악구',
#   'local3': '봉천동',
#   'manage_cost': '10만원',
#   'manage_cost_inc': '수도,인터넷,TV',
#   'movein_date': '즉시 입주',
#   'near_subways': '서울대입구역(2호선), 봉천역(2호선), 숭실대입구역(7호선)',
#   'options': '에어컨,냉장고,세탁기,인덕션,책상,책장,옷장,신발장,싱크대',
#   'original_user_phone': '010-8073-5731',
#   'parking': '불가능',
#   'pets_text': '확인필요',
#   'pnu': '1162010100100410670',
#   'premium_items': [],
#   'profile_url': 'http://ic.zigbang.com/vp/profile/17643854/a9ad06cfb63e43ecf7f5a21a959ad519648b0d49.jpg',
#   'random_location': '37.48470935307031,126.95249516622867',
#   'read_updated_at': '2001-01-01',
#   'rent': 42,
#   'room_direction_text': '남서향',
#   'room_gubun_code': '01',
#   'room_type': '오픈형 원룸',
#   'room_type_code': '01',
#   'sales_type': '월세',
#   'secret_memo': None,
#   'service_type': '원룸',
#   'size': 6,
#   'size_contract': 0,
#   'size_m2': 19.83,
#   'size_m2_contract': '-',
#   'status': '광고중',
#   'title': '💖신축급컨디션✅샤로수길인접👍고층화이트톤✨',
#   'updated_at': '13일 전',
#   'updated_at2': '2022-04-11',
#   'user_email': 'cjsrlgh1@gmail.com',
#   'user_has_no_penalty': True,
#   'user_has_penalty': False,
#   'user_intro': '안녕하세요 언제나 노력하는 구름부동산입니다^^\r\n'
#                 '\r\n'
#                 '⭐고객님들에게 친절은 기본!! 안전한 부동산 거래를 원칙으로하며\r\n'
#                 '가족이라 생각하고 고객님의 입장에서 생각하며 계약에서부터 \r\n'
#                 '입주까지 책임지고 도와드리겠습니다⭐\r\n'
#                 '\r\n'
#                 '💖생생한100% 실사진 실가격으로 더욱 좋은 매물 선보이도록 \r\n'
#                 '매일매일 열심히 뛰겠습니다!! \r\n'
#                 '구름부동산 주소: 서울특별시 관악구 봉천동 1611-1번지 1층',
#   'user_mobile': '0504-3130-6720',
#   'user_name': '소속공인중개사 김종민',
#   'user_no': 17643854,
#   'user_phone': '0504-3130-6720',
#   'view_count': '218'}

# %%
filtered_result = export_items(result)
len(filtered_result)
# Out:
# 26

# %%
def get_full_address(item):
    addr = item['address1']
    addr += ' '
    addr += item['address2'] or ''
    addr += ' '
    addr += item['address3'] or ''
    return addr
geo_based_dict = {}
for item in filtered_result:
    full_addr = get_full_address(item)
    item['address'] = full_addr
    if full_addr not in geo_based_dict:
        geo_based_dict[full_addr] = []
    geo_based_dict[full_addr].append(item)
first_key = next(iter(geo_based_dict))
pp.pprint(geo_based_dict[first_key][0])
double_list = []
for addr in geo_based_dict.keys():
    double_list.append(geo_based_dict[addr][0])
double_list.sort(key=lambda x: x['size'], reverse=True)
# 원하는 조건 가진 아이템을 csv 형식으로 파일을 만든다.

with open('eggs.csv', 'w', newline='') as csvfile:
    fieldnames = [
        'id',
        'title',
        'description',
        'deposit',
        'agent_name',
        'agent_mobile',
        '_floor',
        'address',
        'size',
        'size_m2',
        'status',
        'room_type',
        'manage_cost_inc',
        'updated_at2',
        'url',
    ]
    writer = csv.DictWriter(csvfile, extrasaction='ignore', fieldnames=fieldnames)
    writer.writeheader()
    for item in double_list:
        writer.writerow(item)
# Out:
# { '_floor': '4층',
#   'address': '서울시 관악구 신림동 99-39 ',
#   'address1': '서울시 관악구 신림동',
#   'address2': '99-39',
#   'address3': None,
#   'agent_mobile': '010-4711-7462',
#   'agent_name': '동그라미공인중개사사무소(정승우)',
#   'deposit': 5000,
#   'description': '서림동 서원역(5월개통) 도보 7분거리에 \r\n'
#                  '전세자금대출 가능한  집이 나왔습니다^^\r\n'
#                  '\r\n'
#                  '⚘금액⚘\r\n'
#                  '✔전세금 5000만원 [전세자금대출가능^^]\r\n'
#                  '✔관리비 5만원(인터넷, TV,수도,정화비)포함, 전기,가스별도^^ \r\n'
#                  '\r\n'
#                  '⚘ 방구조 ⚘ \r\n'
#                  '✔ 오픈형 구조로 공간활용을 넓게 사용가능해요 ^^ \r\n'
#                  '✔ 창문이 커서 채광과 통풍이 잘되요 선글라스필수^^ \r\n'
#                  '\r\n'
#                  '⚘ 주변환경 및 교통편 ⚘ \r\n'
#                  '✔ 서원역 도보7분거리에 위치해 있습니다^^  \r\n'
#                  '✔ 버스 정류장옆이라 교통이 뛰어나고 편리해요^^ \r\n'
#                  '✔ 대로변 인근이라 치안이 좋고 cctv 및 보안이 짱짱해요 \r\n'
#                  '✔ 주변에 대형마트, 편의점, 맛집등 편의시설이 좋아요\r\n'
#                  '\r\n'
#                  '⚘ 옵션 ⚘ \r\n'
#                  '✔ tv, 옷장, 인덕션, 냉장고, 에어컨 풀옵션! 몸만 들어오시면 됩니다 \r\n'
#                  '✔ 디지털도어락 과 층별 cctv로 이중안전구조! 여성분들 걱정 ㄴㄴ해!\n'
#                  '22.04.21에 직방에 등록된 매물입니다.',
#   'id': 31509121,
#   'manage_cost_inc': '수도,인터넷,TV',
#   'room_type': '오픈형 원룸',
#   'size': 6.7,
#   'size_m2': 22.15,
#   'status': '광고중',
#   'title': '💘전세대출가능💘서림동💘오픈형💘가성비굿💘풀옵션',
#   'updated_at2': '2022-04-21',
#   'url': 'https://zigbang.com/home/oneroom/items/31509121'}
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Input In [10], in <cell line: 23>()
#      42 writer.writeheader()
#      43 for item in double_list:
# ---> 44     writer.writerow(item)
#
# File C:\anaconda\lib\csv.py:154, in DictWriter.writerow(self, rowdict)
#     153 def writerow(self, rowdict):
# --> 154     return self.writer.writerow(self._dict_to_list(rowdict))
#
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f525' in position 9: illegal multibyte sequence
